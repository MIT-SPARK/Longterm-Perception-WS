# %%
import cv2
import matplotlib.pyplot as plt

# %%
img = cv2.imread('Jen.jpeg')

# %%
img = cv2.imread('filters_no_upscale().webp')

# %%
plt.imshow(img[:,:,::-1])

# %%
plt.imshow(img[30:514,:,::-1])

# %%
img[30:514,:,::-1].shape
# Out:
# (484, 480, 3)

# %%
cv2.imwrite('iro.png',img[30:514,:,:])
# Out:
# True

# %%
plt.imshow(img[20:195,:,::-1])

# %%
plt.imshow(img[10:205,:,::-1])
