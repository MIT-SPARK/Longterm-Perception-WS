# %%
import cv2
import matplotlib.pyplot as plt

# %%
img = cv2.imread('federico_original.jpg')

# %%
img = cv2.imread('filters_no_upscale().webp')

# %%
plt.imshow(img[:,:,::-1])

# %%
plt.imshow(img[15:140,:,::-1])

# %%
img[15:140,:,::-1].shape
# Out:
# (125, 126, 3)

# %%
cv2.imwrite('jianhao.png',img[1800:2600,1200:2000,:])
# Out:
# True

# %%
plt.imshow(img[20:195,:,::-1])

# %%
plt.imshow(img[10:205,:,::-1])
